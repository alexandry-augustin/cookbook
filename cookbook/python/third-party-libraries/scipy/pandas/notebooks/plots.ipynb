# %%
# %matplotlib inline
import numpy as np
import pandas as pd

# %%
data=pd.DataFrame({"time":range(200,300), "col1":np.random.normal(size=100), "col2":np.random.normal(size=100)})

# %%
data.plot()

# %%
data=data.set_index("time")

# %%
data.plot()

# %%
# Out:
# '/home/alex/shared/cs/languages/generic/python/my_projects_python/python_pylab/python_pandas/notebooks'
