# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.DataFrame([[1, 2], [3, 4]], columns=list('AB'))
df["New"]=pd.DataFrame(df["B"]-df["A"])
df
# Out:
#    A  B  New
# 0  1  2    1
# 1  3  4    1

# %%
if 'A' and 'C' in df.columns:
    print "A exist"

# %%
df = pd.DataFrame({"A":[1, 2]})
df["A"]=df["A"].apply(np.sqrt)
df
# Out:
#           A
# 0  1.000000
# 1  1.414214

# %%
df = pd.DataFrame({"A":[1.398, 2.857]})
df["A"]=df["A"].apply(lambda x: float("%.1f"%x))
df
# Out:
#      A
# 0  1.4
# 1  2.9

# %%
data=pd.read_csv("./datasets/data.csv", sep=",")
data
# Out:
#     EmployeeId  GroupId              Name    Salary
# 0            1        1  Demaryius Thomas   85512.0
# 1            2        1       Jacob Tamme   75372.0
# 2            3        2  Demaryius Thomas   80916.0
# 3            4        3   Brandon Stokley   99648.0
# 4            5        3     Joel Dreessen   89440.0
# 5            6        4     Joel Dreessen   78012.0
# 6            7        4       Eric Decker   80724.0
# 7            8        4        Lance Ball    2756.0
# 8            9        5     Joel Dreessen   41784.0
# 9           10        5       Eric Decker   62832.0
# 10          11        5   Brandon Stokley   43104.0
# 11          12        6  Demaryius Thomas   75372.0
# 12          13        6       Eric Decker   87792.0
# 13          14        6   Brandon Stokley   75372.0
# 14          15        7       Eric Decker   19167.2
# 15          16        7  Demaryius Thomas   75372.0
# 16          17        7       Eric Decker   96384.0
# ...

# %%
data[["EmployeeId", "GroupId"]]
# Out:
#     EmployeeId  GroupId
# 0            1        1
# 1            2        1
# 2            3        2
# 3            4        3
# 4            5        3
# 5            6        4
# 6            7        4
# 7            8        4
# 8            9        5
# 9           10        5
# 10          11        5
# 11          12        6
# 12          13        6
# 13          14        6
# 14          15        7
# 15          16        7
# 16          17        7
# 17          18        8
# 18          19        8
# 19          20        8
# 20          21        9
# 21          22       10
# 22          23       10
# 23          24       10
# 24          25       11
# 25          26       11
# 26          27       12
# 27          28       12
# 28          29       12
# 29          30       13
# 30          31       14
# 31          32       15
# 32          33       15
# 33          34       15
# 34          35       16
# 35          36       16
# 36          37       16

# %%
data[data["GroupId"]==1]
# Out:
#    EmployeeId  GroupId              Name  Salary
# 0           1        1  Demaryius Thomas   85512
# 1           2        1       Jacob Tamme   75372

# %%
data.groupby("GroupId").mean()["Salary"].plot()

# %%
#df = pd.DataFrame({"x":[1,2,3,4], "y1":[1, 3], "y2":[2, 4]})
x = pd.DataFrame({"x":[1,2,3,4]})
y1 = pd.DataFrame({"x":[1,3], "y":[1,2]})
y2 = pd.DataFrame({"x":[2,4], "y":[2,1]})
df
#fig,ax=plt.subplots()
#df["y1"].plot(ax=ax)
#df["y2"].plot(ax=ax)
# Out:
#    x
# 0  1
# 1  2
# 2  3
# 3  4

# %% [markdown]
# # Panel
